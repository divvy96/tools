# %%
import pandas
from prophet import Prophet
import yfinance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_13834/897905562.py in <module>
#       1 import pandas
# ----> 2 from prophet import Prophet
#       3 import yfinance
#
# ModuleNotFoundError: No module named 'prophet'

# %%
stocks = {'Vodafone': 'VOD', 'Apple': 'AAPL'}

# %%
df_vodafone = yfinance.Ticker(stocks['Vodafone']).history(period='max')

# %%
df_vodafone['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
v = df_vodafone['Close']

# %%
df_vodafone
# Out:
#                  Open       High        Low  Close   Volume  Dividends  \
# Date
# 2021-09-16  16.170000  16.299999  16.049999  16.23  3981600          0
# 2021-09-17  16.110001  16.170000  15.920000  15.97  5018700          0
# 2021-09-20  15.800000  15.900000  15.700000  15.85  7377000          0
# 2021-09-21  15.890000  15.940000  15.750000  15.78  5386700          0
# 2021-09-22  15.880000  16.110001  15.880000  15.95  5216800          0
# 2021-09-23  15.960000  16.049999  15.930000  16.00  4276700          0
# 2021-09-24  15.830000  15.890000  15.790000  15.85  3884600          0
# 2021-09-27  16.010000  16.219999  16.000000  16.17  5871600          0
# 2021-09-28  15.950000  15.990000  15.710000  15.73  4326600          0
# 2021-09-29  15.660000  15.800000  15.610000  15.69  4059100          0
# 2021-09-30  15.650000  15.670000  15.400000  15.45  4613200          0
# 2021-10-01  15.500000  15.570000  15.370000  15.51  3794600          0
# ...
